# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
from sklearn.metrics import confusion_matrix
import pandas as pd

# Manually defined 6x6 arrays filled with example numbers
array1 = np.array([
    [23, 0, 0, 0, 8, 1],
    [7, 34, 0, 0, 30, 3],
    [13, 0, 13, 0, 41, 15],
    [4, 3, 1, 14, 145, 0],
    [69, 6, 0, 0, 321, 8],
    [1, 0, 0, 0, 1, 6]
])

array2 = np.array([
    [16, 0, 0, 15, 0, 0],
    [6, 33, 2, 9, 14, 10],
    [1, 0, 11, 60, 8, 2],
    [3, 1, 0, 156, 5, 2],
    [39, 1, 31, 267, 63, 3],
    [0, 0, 0, 5, 1, 2 ]
])

array3 = np.array([
    [7, 1, 17, 0, 2, 4 ],
    [6, 48, 1, 1, 13, 5 ],
    [2, 1, 71, 0, 0, 8 ],
    [7, 16, 5, 85, 49, 4 ],
    [32, 32, 111, 25, 181, 23 ],
    [0, 3, 1, 0, 0, 3 ]
])

array4 = np.array([
    [1, 4, 0, 0, 25, 1 ],
    [0, 47, 0, 0, 27, 0 ],
    [0, 0, 0, 1, 78, 2 ],
    [0, 10, 0, 63, 91, 2 ],
    [3, 32, 2, 13, 343, 10 ],
    [0, 0, 0, 0, 7, 0 ]
])

array5 = np.array([
    [19, 0, 1, 1, 4, 6 ],
    [6, 51, 0, 0, 12, 4 ],
    [6, 0, 40, 1, 4, 30 ],
    [36, 3, 3, 72, 43, 9 ],
    [57, 13, 4, 8, 272, 49 ],
    [1, 0, 0, 0, 0, 6 ]
])

# Sum all six arrays together
cm = array1 + array2 + array3 + array4 + array5

class_labels = ['bright_dune', 'crater', 'dark_dune', 'edge', 'other', 'streak']

plt.figure(figsize = (8,8))
sn.heatmap(cm, annot=True, fmt="d", cmap="Reds", cbar=False,
            xticklabels=class_labels, yticklabels=class_labels) # font size
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
